# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# you can change place, range of time and product
data_form = """ctl00$ScriptManager_Master:ctl00$ScriptManager_Master|ctl00$contentPlaceHolder$btnQuery
__EVENTTARGET:
__EVENTARGUMENT:
__VIEWSTATE:...
__VIEWSTATEGENERATOR:924237A5
__EVENTVALIDATION:
ctl00$contentPlaceHolder$ucDateScope$rblDateScope:P
ctl00$contentPlaceHolder$ucSolarLunar$radlSolarLunar:S
ctl00$contentPlaceHolder$txtSTransDate:106/11/05
ctl00$contentPlaceHolder$txtETransDate:106/11/06
ctl00$contentPlaceHolder$txtMarket:全部市場
ctl00$contentPlaceHolder$hfldMarketNo:ALL
ctl00$contentPlaceHolder$txtProduct:全部產品
ctl00$contentPlaceHolder$hfldProductNo:ALL
ctl00$contentPlaceHolder$hfldProductType:A
__ASYNCPOST:true
ctl00$contentPlaceHolder$btnQuery:查詢"""

headers_string = """Accept:*/*
Accept-Encoding:gzip, deflate
Accept-Language:zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4
Cache-Control:no-cache
Connection:keep-alive
Content-Length:1633
Content-Type:application/x-www-form-urlencoded; charset=UTF-8
Cookie:ASP.NET_SessionId=rrezkmxgbaf2f5ushmba1odl
Host:amis.afa.gov.tw
Origin:http://amis.afa.gov.tw
Referer:http://amis.afa.gov.tw/veg/VegProdDayTransInfo.aspx
User-Agent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36
X-MicrosoftAjax:Delta=true
X-Requested-With:XMLHttpRequest"""

data = {line.split(":")[0]: line.split(":")[1] for line in data_form.split()}
headers = {line.split(":")[0]: line.split(":")[1] for line in headers_string.split("\n")}

resp = requests.post("http://amis.afa.gov.tw/veg/VegProdDayTransInfo.aspx", data = data, headers=headers)

# %%
df = pd.read_html(resp.text)
table = df[2]
table.columns = table.iloc[0]
table.drop(["跟前一交易日比較%", "跟前一交易日比較%"], inplace=True, axis=1)
table = table[2:]
table = table.reset_index(drop=True)
table[["市場編號", "市場"]] = table["市場"].str.split(" ",expand=True)
table[["產品編號", "產品"]] = pd.DataFrame([[x.split()[0], " ".join(x.split()[1:])] for x in table["產品"].tolist()])

# %%
table
# Out:
# 0            日期   市場          產品     上價     中價     下價 平均價(元/公斤) 交易量(公斤) 市場編號  \
# 0     106/11/05  台北二         黃秋葵  105.5   57.2   25.9      60.6    1204  104
# 1     106/11/05  台北二  花椰菜 青梗 留梗柄   75.8   57.6   34.9      56.7    6691  104
# 2     106/11/05  台北二       胡瓜 黑刺   33.4   27.5   12.9      25.7    8252  104
# 3     106/11/05  台北二         花胡瓜   47.4   33.0   19.8      33.2   12476  104
# 4     106/11/05  台北二       冬瓜 白皮   13.6   11.3    6.9      10.9    2633  104
# 5     106/11/05  台北二       絲瓜 其他   41.2   29.6   20.4      30.1     221  104
# 6     106/11/05  台北二          絲瓜   35.6   25.2   17.4      25.7   13280  104
# 7     106/11/05  台北二       絲瓜 角瓜   23.3   17.7   12.0      17.7     471  104
# 8     106/11/05  台北二       苦瓜 其他   68.8   51.0   36.7      51.7    1552  104
# 9     106/11/05  台北二      苦瓜 白大米   97.0   67.7   45.6      69.1    2822  104
# 10    106/11/05  台北二      苦瓜 青大米   36.7   35.0   35.0      35.3     683  104
# 11    106/11/05  台北二      苦瓜 山苦瓜   70.0   70.0   70.0      70.0      13  104
# 12    106/11/05  台北二       苦瓜 翠綠   57.9   35.1   23.3      37.3     293  104
# 13    106/11/05  台北二       扁蒲 長形    3.0    3.0    3.0       3.0      20  104
# 14    106/11/05  台北二       扁蒲 圓形    5.0    5.0    5.0       5.0     252  104
# 15    106/11/05  台北二       扁蒲 花蒲   16.0   11.3    3.1      10.6    3314  104
# 16    106/11/05  台北二      扁蒲 梨子蒲   22.5   13.7    5.9      13.9    7054  104
# 17    106/11/05  台北二      茄子 胭脂茄   50.0   44.3   38.2      44.2    1190  104
# 18    106/11/05  台北二      茄子 麻荸茄   65.0   37.8   26.0      40.9    3556  104
# 19    106/11/05  台北二      茄子 日本種   35.0   31.8   30.0      32.1     105  104
# 20    106/11/05  台北二       番茄 黑柿   93.2   62.0   37.9      63.4     418  104
# 21    106/11/05  台北二       番茄 粉柿   99.3   79.3   70.0      81.4      70  104
# 22    106/11/05  台北二      番茄 牛蕃茄  111.2   71.6   46.5      74.5    5382  104
# 23    106/11/05  台北二       甜椒 其他  105.0  105.0  105.0     105.0      33  104
# 24    106/11/05  台北二       甜椒 新香   55.0   55.0   55.0      55.0      20  104
# 25    106/11/05  台北二      甜椒 彩色種  156.9   94.5   59.8     100.0    1492  104
# 26    106/11/05  台北二       甜椒 青椒   88.1   53.9   27.9      55.6    3157  104
# 27    106/11/05  台北二       甜椒 進口   42.0   42.0   42.0      42.0     200  104
# 28    106/11/05  台北二       豌豆 紅花  230.0  230.0  230.0     230.0      48  104
# 29    106/11/05  台北二      豌豆 豌豆苗  150.0  150.0  150.0     150.0     295  104
# ...         ...  ...         ...    ...    ...    ...       ...     ...  ...
# 1410  106/11/06  花蓮市       菜豆 青色   52.1   32.1   22.2      34.1     103  950
# 1411  106/11/06  花蓮市       敏豆 白豆  120.0   92.6   52.6      90.1     298  950
# 1412  106/11/06  花蓮市       敏豆 粉豆  127.7  118.5   65.8     109.8      56  950
# 1413  106/11/06  花蓮市      南瓜 木瓜形   30.0   28.5   24.1      27.9     527  950
# 1414  106/11/06  花蓮市      隼人瓜 瓜苗   65.0   65.0   65.0      65.0      40  950
# 1415  106/11/06  花蓮市       辣椒 紅小  150.0  138.2  125.0     137.9      60  950
# 1416  106/11/06  花蓮市       辣椒 青小   83.0   79.0   62.5      76.5     411  950
# 1417  106/11/06  花蓮市       辣椒 雞心   20.0   20.0   20.0      20.0       1  950
# 1418  106/11/06  花蓮市      玉米 甜硬殼   44.9   38.0   20.1      35.8     600  950
# 1419  106/11/06  花蓮市       落花生 生   90.3   77.6   66.0      77.8     274  950
# 1420  106/11/06  花蓮市       甘藍 初秋   25.8   18.0    8.1      17.6    2872  950
# 1421  106/11/06  花蓮市      甘藍 甜甘藍   37.0   29.1   18.4      28.5   16293  950
# 1422  106/11/06  花蓮市      甘藍 甘藍芽   42.9   26.9   21.0      28.9     755  950
# 1423  106/11/06  花蓮市     包心白 成功白   39.0   30.1   19.8      29.8    2999  950
# 1424  106/11/06  花蓮市     紅鳳菜 紅鳳菜   66.0   64.8   36.0      59.3      61  950
# 1425  106/11/06  花蓮市       蕨菜 過貓   55.0   49.9   41.0      49.2     159  950
# 1426  106/11/06  花蓮市       鹹菜 帶葉   18.0   17.2   14.1      17.2     135  950
# 1427  106/11/06  花蓮市          其他   53.5   21.4    5.7      24.7    4509  950
# 1428  106/11/06  花蓮市       蘿蔔 梅花   25.0   21.4   14.5      20.7     881  950
# 1429  106/11/06  花蓮市       青蔥 日蔥   95.0   88.4   81.2      88.3     120  950
# 1430  106/11/06  花蓮市       韭菜 白頭   90.0   90.0   90.0      90.0      49  950
# 1431  106/11/06  花蓮市         萵苣莖   46.0   44.5   43.0      44.5      46  950
# 1432  106/11/06  花蓮市      芋 檳榔心芋   32.2   28.7   19.6      27.6    2004  950
# 1433  106/11/06  花蓮市        芋 里芋   39.0   39.0   39.0      39.0     104  950
# 1434  106/11/06  花蓮市        芋 芋莖   20.0   13.4   12.0      14.4     108  950
# 1435  106/11/06  花蓮市    甘薯 臺農57號   17.2   10.7    6.3      11.1    1822  950
# 1436  106/11/06  花蓮市     甘薯 芋仔甘薯   28.0   28.0   28.0      28.0      70  950
# 1437  106/11/06  花蓮市        薑 老薑  107.9   46.2   20.8      53.5    1136  950
# 1438  106/11/06  花蓮市        薑 嫩薑   28.6   20.5   10.5      20.1    1971  950
# 1439  106/11/06  花蓮市      薯蕷 紅薯蕷   90.0   90.0   90.0      90.0      39  950
#
# 0     產品編號
# 0      FA1
# 1     FB11
# 2      FC1
# 3      FD1
# 4      FE1
# 5      FF0
# 6      FF1
# 7      FF2
# 8      FG0
# 9      FG1
# 10     FG2
# 11     FG3
# 12     FG4
# 13     FH1
# 14     FH2
# 15     FH3
# 16     FH4
# 17     FI1
# 18     FI2
# 19     FI3
# 20     FJ1
# 21     FJ2
# 22     FJ3
# 23     FK0
# 24     FK3
# 25     FK4
# 26     FK5
# 27     FK9
# 28     FL2
# 29     FL5
# ...    ...
# 1410   FM2
# 1411   FN1
# 1412   FN3
# 1413   FT1
# 1414   FU2
# 1415   FV1
# 1416   FV2
# 1417   FV3
# 1418   FY2
# 1419   FZ1
# 1420   LA1
# 1421   LA3
# 1422   LA6
# 1423   LC2
# 1424   LQ1
# 1425   LX1
# 1426   OA2
# 1427   OX1
# 1428   SA1
# 1429   SE1
# 1430   SF1
# 1431   SI1
# 1432   SJ2
# 1433   SJ3
# 1434   SJ4
# 1435   SO1
# 1436   SO2
# 1437   SP1
# 1438   SP2
# 1439   SU1
#
# [1440 rows x 10 columns]
