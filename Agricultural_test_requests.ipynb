# %%
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd

# fill begining date, ending date in order
data_form = """ctl00$ScriptManager_Master:ctl00$ScriptManager_Master|ctl00$contentPlaceHolder$btnQuery
__EVENTTARGET:
__EVENTARGUMENT:
__VIEWSTATE:...
__VIEWSTATEGENERATOR:924237A5
__EVENTVALIDATION:
ctl00$contentPlaceHolder$ucDateScope$rblDateScope:P
ctl00$contentPlaceHolder$ucSolarLunar$radlSolarLunar:S
ctl00$contentPlaceHolder$txtSTransDate:
ctl00$contentPlaceHolder$txtETransDate:
ctl00$contentPlaceHolder$txtMarket:全部市場
ctl00$contentPlaceHolder$hfldMarketNo:ALL
ctl00$contentPlaceHolder$txtProduct:全部產品
ctl00$contentPlaceHolder$hfldProductNo:ALL
ctl00$contentPlaceHolder$hfldProductType:A
__ASYNCPOST:true
ctl00$contentPlaceHolder$btnQuery:查詢"""

headers_string = """Accept:*/*
Accept-Encoding:gzip, deflate
Accept-Language:zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4
Cache-Control:no-cache
Connection:keep-alive
Content-Length:1633
Content-Type:application/x-www-form-urlencoded; charset=UTF-8
Cookie:ASP.NET_SessionId=rrezkmxgbaf2f5ushmba1odl
Host:amis.afa.gov.tw
Origin:http://amis.afa.gov.tw
Referer:http://amis.afa.gov.tw/veg/VegProdDayTransInfo.aspx
User-Agent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36
X-MicrosoftAjax:Delta=true
X-Requested-With:XMLHttpRequest"""

headers = {line.split(":")[0]: line.split(":")[1] for line in headers_string.split("\n")}
data = {line.split(":")[0]: line.split(":")[1] for line in data_form.split()}

# %%
data["ctl00$contentPlaceHolder$txtSTransDate"] = "106/11/04"
data["ctl00$contentPlaceHolder$txtETransDate"] = "106/11/05"
resp = requests.post("http://amis.afa.gov.tw/veg/VegProdDayTransInfo.aspx", data = data, headers=headers)
df = pd.read_html(resp.text)

# %%
df[2]
# Out:
#               0        1                2      3      4      5          6  \
# 0            日期       市場               產品     上價     中價     下價  平均價(元/公斤)
# 1            小計      NaN              NaN    NaN   34.0    NaN    6270540
# 2     106/11/04  104 台北二          FA1 黃秋葵  115.2   62.2   26.3       65.6
# 3     106/11/04  104 台北二        FA9 百果 進口  250.0  250.0  250.0      250.0
# 4     106/11/04  104 台北二  FB11 花椰菜 青梗 留梗柄   79.4   63.1   38.5       61.5
# 5     106/11/04  104 台北二        FC1 胡瓜 黑刺   38.4   28.7   13.1       27.5
# 6     106/11/04  104 台北二          FD1 花胡瓜   55.5   39.9   22.8       39.5
# 7     106/11/04  104 台北二        FE1 冬瓜 白皮    9.5    7.1    4.5        7.0
# 8     106/11/04  104 台北二        FF0 絲瓜 其他   38.0   34.4   23.3       32.9
# 9     106/11/04  104 台北二           FF1 絲瓜   42.5   31.4   21.3       31.6
# 10    106/11/04  104 台北二        FF2 絲瓜 角瓜   37.1   23.8   14.7       24.6
# 11    106/11/04  104 台北二        FG0 苦瓜 其他   70.1   56.0   31.3       53.9
# 12    106/11/04  104 台北二       FG1 苦瓜 白大米  102.3   67.4   40.6       69.0
# 13    106/11/04  104 台北二       FG2 苦瓜 青大米   40.4   35.0   35.0       36.1
# 14    106/11/04  104 台北二       FG3 苦瓜 山苦瓜   80.0   80.0   80.0       80.0
# 15    106/11/04  104 台北二        FG4 苦瓜 翠綠   59.2   34.3   26.6       37.7
# 16    106/11/04  104 台北二        FH2 扁蒲 圓形   20.0   20.0   20.0       20.0
# 17    106/11/04  104 台北二        FH3 扁蒲 花蒲   23.2   16.7    9.2       16.5
# 18    106/11/04  104 台北二       FH4 扁蒲 梨子蒲   31.1   22.9   14.9       22.9
# 19    106/11/04  104 台北二       FI1 茄子 胭脂茄   51.1   44.9   36.0       44.4
# 20    106/11/04  104 台北二       FI2 茄子 麻荸茄   65.2   41.5   26.3       43.2
# 21    106/11/04  104 台北二       FI3 茄子 日本種   35.7   28.3   20.0       28.1
# 22    106/11/04  104 台北二        FJ1 番茄 黑柿  108.7   77.3   44.0       76.9
# 23    106/11/04  104 台北二       FJ3 番茄 牛蕃茄  100.5   65.0   29.9       65.1
# 24    106/11/04  104 台北二        FK0 甜椒 其他  125.0  121.7  110.0      120.0
# 25    106/11/04  104 台北二        FK3 甜椒 新香   50.0   50.0   50.0       50.0
# 26    106/11/04  104 台北二       FK4 甜椒 彩色種  160.4  122.2   64.4      118.3
# 27    106/11/04  104 台北二        FK5 甜椒 青椒  104.0   55.0   31.5       60.1
# 28    106/11/04  104 台北二       FL5 豌豆 豌豆苗  150.0  150.0   81.4      136.3
# 29    106/11/04  104 台北二       FL6 豌豆 甜豌豆  243.0  222.6  200.0      222.2
# ...         ...      ...              ...    ...    ...    ...        ...
# 3041  106/11/04  950 花蓮市        FK5 甜椒 青椒   90.0   84.0   61.5       80.7
# 3042  106/11/04  950 花蓮市        FM2 菜豆 青色   60.0   55.1   40.4       53.2
# 3043  106/11/04  950 花蓮市        FN1 敏豆 白豆  153.9  110.1   77.6      112.3
# 3044  106/11/04  950 花蓮市       FT1 南瓜 木瓜形   26.4   22.6   20.2       22.9
# 3045  106/11/04  950 花蓮市       FU2 隼人瓜 瓜苗   65.0   65.0   65.0       65.0
# 3046  106/11/04  950 花蓮市        FV1 辣椒 紅小  140.0  131.6   97.9      126.5
# 3047  106/11/04  950 花蓮市        FV2 辣椒 青小   90.0   88.3   69.0       84.8
# 3048  106/11/04  950 花蓮市        FV3 辣椒 雞心  100.0  100.0  100.0      100.0
# 3049  106/11/04  950 花蓮市        FV5 辣椒 青龍  150.0  150.0  150.0      150.0
# 3050  106/11/04  950 花蓮市       FY1 玉米 白玉米   20.0   20.0   20.0       20.0
# 3051  106/11/04  950 花蓮市       FY2 玉米 甜硬殼   46.8   34.8   16.9       33.7
# 3052  106/11/04  950 花蓮市        FZ1 落花生 生   90.0   85.2   66.2       85.2
# 3053  106/11/04  950 花蓮市        LA1 甘藍 初秋   26.1   21.8   15.9       21.5
# 3054  106/11/04  950 花蓮市       LA3 甘藍 甜甘藍   41.0   30.7   21.4       30.9
# 3055  106/11/04  950 花蓮市       LA6 甘藍 甘藍芽   50.0   49.0   46.7       48.8
# 3056  106/11/04  950 花蓮市      LC2 包心白 成功白   38.0   35.0   28.9       34.4
# 3057  106/11/04  950 花蓮市       LJ3 芥菜 大芥菜   20.0   20.0   20.0       20.0
# 3058  106/11/04  950 花蓮市      LQ1 紅鳳菜 紅鳳菜   75.0   74.5   59.1       71.5
# 3059  106/11/04  950 花蓮市        LX1 蕨菜 過貓   70.0   67.3   58.0       66.0
# 3060  106/11/04  950 花蓮市        LX2 蕨菜 山蘇   70.0   63.7   48.1       61.9
# 3061  106/11/04  950 花蓮市           OX1 其他   42.2   14.3    6.6       18.3
# 3062  106/11/04  950 花蓮市        SA1 蘿蔔 梅花   26.1   21.0   14.1       20.6
# 3063  106/11/04  950 花蓮市        SE1 青蔥 日蔥   90.0   90.0   90.0       90.0
# 3064  106/11/04  950 花蓮市        SF1 韭菜 白頭   90.0   83.7   81.9       84.6
# 3065  106/11/04  950 花蓮市       SJ2 芋 檳榔心芋   31.0   28.7   20.4       27.5
# 3066  106/11/04  950 花蓮市         SJ4 芋 芋莖   16.0   11.7   10.0       13.1
# 3067  106/11/04  950 花蓮市     SO1 甘薯 臺農57號   16.8   14.4   10.5       14.1
# 3068  106/11/04  950 花蓮市      SO2 甘薯 芋仔甘薯   22.0   19.5   16.0       19.3
# 3069  106/11/04  950 花蓮市         SP1 薑 老薑  110.0   78.5   45.8       78.3
# 3070  106/11/04  950 花蓮市         SP2 薑 嫩薑   34.4   29.0   19.6       28.2
#
#               7        8          9
# 0     跟前一交易日比較%  交易量(公斤)  跟前一交易日比較%
# 1           NaN      NaN        NaN
# 2           - 5      949        + 6
# 3             -        5          -
# 4             0     5736        - 6
# 5          - 17     5924        + 4
# 6           - 1     8467        - 8
# 7          - 38     4654       - 61
# 8          - 16      177       - 13
# 9          - 14    11318       + 76
# 10         - 10      388        - 4
# 11          - 9     1635       + 34
# 12         - 15     2592       + 54
# 13            -      560          -
# 14            -       13          -
# 15          - 3      326       - 48
# 16         + 33       20       - 83
# 17          - 6     2337        + 0
# 18          - 9     6235       + 12
# 19          - 1     1357       + 67
# 20          - 5     5299        + 9
# 21         + 10      199       + 49
# 22          - 6      392       + 39
# 23         - 20     8557       + 39
# 24          - 9       33          0
# 25            -       10          -
# 26         - 15     1892       +105
# 27          - 9     2199        + 5
# 28          - 9      272       + 39
# 29          - 2      115       + 17
# ...         ...      ...        ...
# 3041       + 12      743       +400
# 3042       - 24      199       +469
# 3043       - 35      346       + 74
# 3044        - 4     1756        - 4
# 3045          0       17       - 11
# 3046        - 8       39       - 34
# 3047       + 12      142       - 57
# 3048          -        4          -
# 3049        + 3       16       + 68
# 3050          -       35          -
# 3051       - 11     1546       + 27
# 3052        + 4       42       - 72
# 3053       - 21     3488       + 33
# 3054       - 17    16506       +105
# 3055        + 1      223       + 66
# 3056        - 8     1756        - 3
# 3057       + 18      208       - 60
# 3058        + 3       54       - 39
# 3059        - 6       36       +177
# 3060       + 15       67       - 46
# 3061       + 33     1672       - 20
# 3062       + 10      841       + 43
# 3063       + 57       76       + 62
# 3064       + 21      144       - 23
# 3065       + 19     1240       - 28
# 3066       + 22      133       - 41
# 3067        - 4      315       - 84
# 3068        - 1      121       - 50
# 3069        - 6      546       - 17
# 3070       + 13     1367       - 11
#
# [3071 rows x 10 columns]
