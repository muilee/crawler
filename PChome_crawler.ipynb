# %%
import requests
from bs4 import BeautifulSoup
import json

# this website is built by javascript, so you should find XHR file to get the url 

url = "http://ecshweb.pchome.com.tw/search/v3.3/all/results?q=ssd&page={}&sort=rnk/dc"
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"}

# you can fill a number in ()
resp = requests.get(url.format(2), headers=headers)
resp.encoding = "utf-8"
jd = json.loads(resp.text)
jd['prods']
# Out:
# [{'Id': 'DHAEBK-A9008EAUB',
#   'author': '',
#   'brand': '',
#   'cateId': 'DHAEBK',
#   'couponActid': ['C006095', 'C006093'],
#   'describe': '全球最薄的13吋筆記型電腦ACER SF713-51-M707七代i5★極薄0.99cm‧極輕1.1kg★256G SSD',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'ACER SF713-51-M707.( i5-7Y54/256GB SSD/W10/FHD)',
#   'picB': '/items/DHAEBKA9008EAUB/000001_1508827336.jpg',
#   'picS': '/items/DHAEBKA9008EAUB/000002_1504850814.jpg',
#   'price': 29900,
#   'publishDate': ''},
#  {'Id': 'DHAFBJ-A9007NJ5I',
#   'author': '',
#   'brand': '',
#   'cateId': 'DHAFFU',
#   'couponActid': [],
#   'describe': '★送雀巢咖啡機(市價$3999)13吋機身,擁有14吋螢幕ASUS UX410UQ 石英灰NV 940M獨顯2G||1.4KG 輕薄外型',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'ASUS UX410UQ-0091A7500U 石英灰 (i7-7500U/FHD/940MX獨顯2G/8G/1TB + 128G SSD/W10)',
#   'picB': '/items/DHAFBJA9007NJ5I/000001_1508725543.jpg',
#   'picS': '/items/DHAFBJA9007NJ5I/000002_1507189719.jpg',
#   'price': 34900,
#   'publishDate': ''},
#  {'Id': 'DHAG4N-A9008F8IA',
# ...
