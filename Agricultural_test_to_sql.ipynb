# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import concurrent.futures
import math
import time

# you can change place, range of time and product
data_form = """ctl00$ScriptManager_Master:ctl00$ScriptManager_Master|ctl00$contentPlaceHolder$btnQuery
__EVENTTARGET:
__EVENTARGUMENT:
__VIEWSTATE:...
__VIEWSTATEGENERATOR:924237A5
__EVENTVALIDATION:
ctl00$contentPlaceHolder$ucDateScope$rblDateScope:P
ctl00$contentPlaceHolder$ucSolarLunar$radlSolarLunar:S
ctl00$contentPlaceHolder$txtSTransDate:106/11/05
ctl00$contentPlaceHolder$txtETransDate:106/11/06
ctl00$contentPlaceHolder$txtMarket:全部市場
ctl00$contentPlaceHolder$hfldMarketNo:ALL
ctl00$contentPlaceHolder$txtProduct:全部產品
ctl00$contentPlaceHolder$hfldProductNo:ALL
ctl00$contentPlaceHolder$hfldProductType:A
__ASYNCPOST:true
ctl00$contentPlaceHolder$btnQuery:查詢"""

headers_string = """Accept:*/*
Accept-Encoding:gzip, deflate
Accept-Language:zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4
Cache-Control:no-cache
Connection:keep-alive
Content-Length:1633
Content-Type:application/x-www-form-urlencoded; charset=UTF-8
Cookie:ASP.NET_SessionId=rrezkmxgbaf2f5ushmba1odl
Host:amis.afa.gov.tw
Origin:http://amis.afa.gov.tw
Referer:http://amis.afa.gov.tw/veg/VegProdDayTransInfo.aspx
User-Agent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36
X-MicrosoftAjax:Delta=true
X-Requested-With:XMLHttpRequest"""

data = {line.split(":")[0]: line.split(":")[1] for line in data_form.split()}
headers = {line.split(":")[0]: line.split(":")[1] for line in headers_string.split("\n")}

resp = requests.post("http://amis.afa.gov.tw/veg/VegProdDayTransInfo.aspx", data = data, headers=headers)

# %%
df = pd.read_html(resp.text)
table = df[2]
table.columns = table.iloc[0]
table.drop(["跟前一交易日比較%", "跟前一交易日比較%"], inplace=True, axis=1)
table = table[2:]
table = table.reset_index(drop=True)
table[["市場編號", "市場"]] = table["市場"].str.split(" ",expand=True)
table[["產品編號", "產品"]] = pd.DataFrame([[x.split()[0], " ".join(x.split()[1:])] for x in table["產品"].tolist()])
table["日期"] = pd.DataFrame([str(int(x.split("/")[0]) + 1911) + "-" + "-".join(x.split("/")[1:]) for x in table["日期"].tolist()])

# %%
table[["市場", "產品", "產品編號", "市場編號", "產品編號"]] = table[["市場", "產品", "產品編號", "市場編號", "產品編號"]].astype(str)
table[["上價", "中價", "下價", "平均價(元/公斤)"]] = table[["上價", "中價", "下價", "平均價(元/公斤)"]].astype("float64")
table["交易量(公斤)"] = table["交易量(公斤)"].astype("int")
table["日期"] = table["日期"].astype("datetime64[ns]")

# %%
table
# Out:
# 0            日期   市場          產品     上價     中價     下價  平均價(元/公斤)  交易量(公斤)  \
# 0    2017-11-05  台北二         黃秋葵  105.5   57.2   25.9       60.6     1204
# 1    2017-11-05  台北二  花椰菜 青梗 留梗柄   75.8   57.6   34.9       56.7     6691
# 2    2017-11-05  台北二       胡瓜 黑刺   33.4   27.5   12.9       25.7     8252
# 3    2017-11-05  台北二         花胡瓜   47.4   33.0   19.8       33.2    12476
# 4    2017-11-05  台北二       冬瓜 白皮   13.6   11.3    6.9       10.9     2633
# 5    2017-11-05  台北二       絲瓜 其他   41.2   29.6   20.4       30.1      221
# 6    2017-11-05  台北二          絲瓜   35.6   25.2   17.4       25.7    13280
# 7    2017-11-05  台北二       絲瓜 角瓜   23.3   17.7   12.0       17.7      471
# 8    2017-11-05  台北二       苦瓜 其他   68.8   51.0   36.7       51.7     1552
# 9    2017-11-05  台北二      苦瓜 白大米   97.0   67.7   45.6       69.1     2822
# 10   2017-11-05  台北二      苦瓜 青大米   36.7   35.0   35.0       35.3      683
# 11   2017-11-05  台北二      苦瓜 山苦瓜   70.0   70.0   70.0       70.0       13
# 12   2017-11-05  台北二       苦瓜 翠綠   57.9   35.1   23.3       37.3      293
# 13   2017-11-05  台北二       扁蒲 長形    3.0    3.0    3.0        3.0       20
# 14   2017-11-05  台北二       扁蒲 圓形    5.0    5.0    5.0        5.0      252
# 15   2017-11-05  台北二       扁蒲 花蒲   16.0   11.3    3.1       10.6     3314
# 16   2017-11-05  台北二      扁蒲 梨子蒲   22.5   13.7    5.9       13.9     7054
# 17   2017-11-05  台北二      茄子 胭脂茄   50.0   44.3   38.2       44.2     1190
# 18   2017-11-05  台北二      茄子 麻荸茄   65.0   37.8   26.0       40.9     3556
# 19   2017-11-05  台北二      茄子 日本種   35.0   31.8   30.0       32.1      105
# 20   2017-11-05  台北二       番茄 黑柿   93.2   62.0   37.9       63.4      418
# 21   2017-11-05  台北二       番茄 粉柿   99.3   79.3   70.0       81.4       70
# 22   2017-11-05  台北二      番茄 牛蕃茄  111.2   71.6   46.5       74.5     5382
# 23   2017-11-05  台北二       甜椒 其他  105.0  105.0  105.0      105.0       33
# 24   2017-11-05  台北二       甜椒 新香   55.0   55.0   55.0       55.0       20
# 25   2017-11-05  台北二      甜椒 彩色種  156.9   94.5   59.8      100.0     1492
# 26   2017-11-05  台北二       甜椒 青椒   88.1   53.9   27.9       55.6     3157
# 27   2017-11-05  台北二       甜椒 進口   42.0   42.0   42.0       42.0      200
# 28   2017-11-05  台北二       豌豆 紅花  230.0  230.0  230.0      230.0       48
# 29   2017-11-05  台北二      豌豆 豌豆苗  150.0  150.0  150.0      150.0      295
# ...         ...  ...         ...    ...    ...    ...        ...      ...
# 1575 2017-11-06  花蓮市       菜豆 青色   52.1   32.1   22.2       34.1      103
# 1576 2017-11-06  花蓮市       敏豆 白豆  120.0   92.6   52.6       90.1      298
# 1577 2017-11-06  花蓮市       敏豆 粉豆  127.7  118.5   65.8      109.8       56
# 1578 2017-11-06  花蓮市      南瓜 木瓜形   30.0   28.5   24.1       27.9      527
# 1579 2017-11-06  花蓮市      隼人瓜 瓜苗   65.0   65.0   65.0       65.0       40
# 1580 2017-11-06  花蓮市       辣椒 紅小  150.0  138.2  125.0      137.9       60
# 1581 2017-11-06  花蓮市       辣椒 青小   83.0   79.0   62.5       76.5      411
# 1582 2017-11-06  花蓮市       辣椒 雞心   20.0   20.0   20.0       20.0        1
# 1583 2017-11-06  花蓮市      玉米 甜硬殼   44.9   38.0   20.1       35.8      600
# 1584 2017-11-06  花蓮市       落花生 生   90.3   77.6   66.0       77.8      274
# 1585 2017-11-06  花蓮市       甘藍 初秋   25.8   18.0    8.1       17.6     2872
# 1586 2017-11-06  花蓮市      甘藍 甜甘藍   37.0   29.1   18.4       28.5    16293
# 1587 2017-11-06  花蓮市      甘藍 甘藍芽   42.9   26.9   21.0       28.9      755
# 1588 2017-11-06  花蓮市     包心白 成功白   39.0   30.1   19.8       29.8     2999
# 1589 2017-11-06  花蓮市     紅鳳菜 紅鳳菜   66.0   64.8   36.0       59.3       61
# 1590 2017-11-06  花蓮市       蕨菜 過貓   55.0   49.9   41.0       49.2      159
# 1591 2017-11-06  花蓮市       鹹菜 帶葉   18.0   17.2   14.1       17.2      135
# 1592 2017-11-06  花蓮市          其他   53.5   21.4    5.7       24.7     4509
# 1593 2017-11-06  花蓮市       蘿蔔 梅花   25.0   21.4   14.5       20.7      881
# 1594 2017-11-06  花蓮市       青蔥 日蔥   95.0   88.4   81.2       88.3      120
# 1595 2017-11-06  花蓮市       韭菜 白頭   90.0   90.0   90.0       90.0       49
# 1596 2017-11-06  花蓮市         萵苣莖   46.0   44.5   43.0       44.5       46
# 1597 2017-11-06  花蓮市      芋 檳榔心芋   32.2   28.7   19.6       27.6     2004
# 1598 2017-11-06  花蓮市        芋 里芋   39.0   39.0   39.0       39.0      104
# 1599 2017-11-06  花蓮市        芋 芋莖   20.0   13.4   12.0       14.4      108
# 1600 2017-11-06  花蓮市    甘薯 臺農57號   17.2   10.7    6.3       11.1     1822
# 1601 2017-11-06  花蓮市     甘薯 芋仔甘薯   28.0   28.0   28.0       28.0       70
# 1602 2017-11-06  花蓮市        薑 老薑  107.9   46.2   20.8       53.5     1136
# 1603 2017-11-06  花蓮市        薑 嫩薑   28.6   20.5   10.5       20.1     1971
# 1604 2017-11-06  花蓮市      薯蕷 紅薯蕷   90.0   90.0   90.0       90.0       39
#
# 0    市場編號  產品編號
# 0     104   FA1
# 1     104  FB11
# 2     104   FC1
# 3     104   FD1
# 4     104   FE1
# 5     104   FF0
# 6     104   FF1
# 7     104   FF2
# 8     104   FG0
# 9     104   FG1
# 10    104   FG2
# 11    104   FG3
# 12    104   FG4
# 13    104   FH1
# 14    104   FH2
# 15    104   FH3
# 16    104   FH4
# 17    104   FI1
# 18    104   FI2
# 19    104   FI3
# 20    104   FJ1
# 21    104   FJ2
# 22    104   FJ3
# 23    104   FK0
# 24    104   FK3
# 25    104   FK4
# 26    104   FK5
# 27    104   FK9
# 28    104   FL2
# 29    104   FL5
# ...   ...   ...
# 1575  950   FM2
# 1576  950   FN1
# 1577  950   FN3
# 1578  950   FT1
# 1579  950   FU2
# 1580  950   FV1
# 1581  950   FV2
# 1582  950   FV3
# 1583  950   FY2
# 1584  950   FZ1
# 1585  950   LA1
# 1586  950   LA3
# 1587  950   LA6
# 1588  950   LC2
# 1589  950   LQ1
# 1590  950   LX1
# 1591  950   OA2
# 1592  950   OX1
# 1593  950   SA1
# 1594  950   SE1
# 1595  950   SF1
# 1596  950   SI1
# 1597  950   SJ2
# 1598  950   SJ3
# 1599  950   SJ4
# 1600  950   SO1
# 1601  950   SO2
# 1602  950   SP1
# 1603  950   SP2
# 1604  950   SU1
#
# [1605 rows x 10 columns]

# %%
table.dtypes
# Out:
# 0
# 日期           datetime64[ns]
# 市場                   object
# 產品                   object
# 上價                  float64
# 中價                  float64
# 下價                  float64
# 平均價(元/公斤)           float64
# 交易量(公斤)               int64
# 市場編號                 object
# 產品編號                 object
# dtype: object

# %%
import sqlalchemy

engine = sqlalchemy.create_engine("mysql+pymysql://root:pythonetl@127.0.0.1:3306/?charset=utf8mb4")
engine.execute("CREATE DATABASE Agriculture CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;")
# Out:
# /home/matt/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)

# %%
engine.execute("USE Agriculture;")

# %%
table.to_sql("product", engine, if_exists='replace', index=False)

# %%
table1 = pd.read_sql_table("product", engine, "Agriculture")
table1
# Out:
# 0            日期   市場          產品     上價     中價     下價  平均價(元/公斤)  交易量(公斤)  \
# 0    2017-11-05  台北二         黃秋葵  105.5   57.2   25.9       60.6     1204
# 1    2017-11-05  台北二  花椰菜 青梗 留梗柄   75.8   57.6   34.9       56.7     6691
# 2    2017-11-05  台北二       胡瓜 黑刺   33.4   27.5   12.9       25.7     8252
# 3    2017-11-05  台北二         花胡瓜   47.4   33.0   19.8       33.2    12476
# 4    2017-11-05  台北二       冬瓜 白皮   13.6   11.3    6.9       10.9     2633
# 5    2017-11-05  台北二       絲瓜 其他   41.2   29.6   20.4       30.1      221
# 6    2017-11-05  台北二          絲瓜   35.6   25.2   17.4       25.7    13280
# 7    2017-11-05  台北二       絲瓜 角瓜   23.3   17.7   12.0       17.7      471
# 8    2017-11-05  台北二       苦瓜 其他   68.8   51.0   36.7       51.7     1552
# 9    2017-11-05  台北二      苦瓜 白大米   97.0   67.7   45.6       69.1     2822
# 10   2017-11-05  台北二      苦瓜 青大米   36.7   35.0   35.0       35.3      683
# 11   2017-11-05  台北二      苦瓜 山苦瓜   70.0   70.0   70.0       70.0       13
# 12   2017-11-05  台北二       苦瓜 翠綠   57.9   35.1   23.3       37.3      293
# 13   2017-11-05  台北二       扁蒲 長形    3.0    3.0    3.0        3.0       20
# 14   2017-11-05  台北二       扁蒲 圓形    5.0    5.0    5.0        5.0      252
# 15   2017-11-05  台北二       扁蒲 花蒲   16.0   11.3    3.1       10.6     3314
# 16   2017-11-05  台北二      扁蒲 梨子蒲   22.5   13.7    5.9       13.9     7054
# 17   2017-11-05  台北二      茄子 胭脂茄   50.0   44.3   38.2       44.2     1190
# 18   2017-11-05  台北二      茄子 麻荸茄   65.0   37.8   26.0       40.9     3556
# 19   2017-11-05  台北二      茄子 日本種   35.0   31.8   30.0       32.1      105
# 20   2017-11-05  台北二       番茄 黑柿   93.2   62.0   37.9       63.4      418
# 21   2017-11-05  台北二       番茄 粉柿   99.3   79.3   70.0       81.4       70
# 22   2017-11-05  台北二      番茄 牛蕃茄  111.2   71.6   46.5       74.5     5382
# 23   2017-11-05  台北二       甜椒 其他  105.0  105.0  105.0      105.0       33
# 24   2017-11-05  台北二       甜椒 新香   55.0   55.0   55.0       55.0       20
# 25   2017-11-05  台北二      甜椒 彩色種  156.9   94.5   59.8      100.0     1492
# 26   2017-11-05  台北二       甜椒 青椒   88.1   53.9   27.9       55.6     3157
# 27   2017-11-05  台北二       甜椒 進口   42.0   42.0   42.0       42.0      200
# 28   2017-11-05  台北二       豌豆 紅花  230.0  230.0  230.0      230.0       48
# 29   2017-11-05  台北二      豌豆 豌豆苗  150.0  150.0  150.0      150.0      295
# ...         ...  ...         ...    ...    ...    ...        ...      ...
# 1575 2017-11-06  花蓮市       菜豆 青色   52.1   32.1   22.2       34.1      103
# 1576 2017-11-06  花蓮市       敏豆 白豆  120.0   92.6   52.6       90.1      298
# 1577 2017-11-06  花蓮市       敏豆 粉豆  127.7  118.5   65.8      109.8       56
# 1578 2017-11-06  花蓮市      南瓜 木瓜形   30.0   28.5   24.1       27.9      527
# 1579 2017-11-06  花蓮市      隼人瓜 瓜苗   65.0   65.0   65.0       65.0       40
# 1580 2017-11-06  花蓮市       辣椒 紅小  150.0  138.2  125.0      137.9       60
# 1581 2017-11-06  花蓮市       辣椒 青小   83.0   79.0   62.5       76.5      411
# 1582 2017-11-06  花蓮市       辣椒 雞心   20.0   20.0   20.0       20.0        1
# 1583 2017-11-06  花蓮市      玉米 甜硬殼   44.9   38.0   20.1       35.8      600
# 1584 2017-11-06  花蓮市       落花生 生   90.3   77.6   66.0       77.8      274
# 1585 2017-11-06  花蓮市       甘藍 初秋   25.8   18.0    8.1       17.6     2872
# 1586 2017-11-06  花蓮市      甘藍 甜甘藍   37.0   29.1   18.4       28.5    16293
# 1587 2017-11-06  花蓮市      甘藍 甘藍芽   42.9   26.9   21.0       28.9      755
# 1588 2017-11-06  花蓮市     包心白 成功白   39.0   30.1   19.8       29.8     2999
# 1589 2017-11-06  花蓮市     紅鳳菜 紅鳳菜   66.0   64.8   36.0       59.3       61
# 1590 2017-11-06  花蓮市       蕨菜 過貓   55.0   49.9   41.0       49.2      159
# 1591 2017-11-06  花蓮市       鹹菜 帶葉   18.0   17.2   14.1       17.2      135
# 1592 2017-11-06  花蓮市          其他   53.5   21.4    5.7       24.7     4509
# 1593 2017-11-06  花蓮市       蘿蔔 梅花   25.0   21.4   14.5       20.7      881
# 1594 2017-11-06  花蓮市       青蔥 日蔥   95.0   88.4   81.2       88.3      120
# 1595 2017-11-06  花蓮市       韭菜 白頭   90.0   90.0   90.0       90.0       49
# 1596 2017-11-06  花蓮市         萵苣莖   46.0   44.5   43.0       44.5       46
# 1597 2017-11-06  花蓮市      芋 檳榔心芋   32.2   28.7   19.6       27.6     2004
# 1598 2017-11-06  花蓮市        芋 里芋   39.0   39.0   39.0       39.0      104
# 1599 2017-11-06  花蓮市        芋 芋莖   20.0   13.4   12.0       14.4      108
# 1600 2017-11-06  花蓮市    甘薯 臺農57號   17.2   10.7    6.3       11.1     1822
# 1601 2017-11-06  花蓮市     甘薯 芋仔甘薯   28.0   28.0   28.0       28.0       70
# 1602 2017-11-06  花蓮市        薑 老薑  107.9   46.2   20.8       53.5     1136
# 1603 2017-11-06  花蓮市        薑 嫩薑   28.6   20.5   10.5       20.1     1971
# 1604 2017-11-06  花蓮市      薯蕷 紅薯蕷   90.0   90.0   90.0       90.0       39
#
# 0    市場編號  產品編號
# 0     104   FA1
# 1     104  FB11
# 2     104   FC1
# 3     104   FD1
# 4     104   FE1
# 5     104   FF0
# 6     104   FF1
# 7     104   FF2
# 8     104   FG0
# 9     104   FG1
# 10    104   FG2
# 11    104   FG3
# 12    104   FG4
# 13    104   FH1
# 14    104   FH2
# 15    104   FH3
# 16    104   FH4
# 17    104   FI1
# 18    104   FI2
# 19    104   FI3
# 20    104   FJ1
# 21    104   FJ2
# 22    104   FJ3
# 23    104   FK0
# 24    104   FK3
# 25    104   FK4
# 26    104   FK5
# 27    104   FK9
# 28    104   FL2
# 29    104   FL5
# ...   ...   ...
# 1575  950   FM2
# 1576  950   FN1
# 1577  950   FN3
# 1578  950   FT1
# 1579  950   FU2
# 1580  950   FV1
# 1581  950   FV2
# 1582  950   FV3
# 1583  950   FY2
# 1584  950   FZ1
# 1585  950   LA1
# 1586  950   LA3
# 1587  950   LA6
# 1588  950   LC2
# 1589  950   LQ1
# 1590  950   LX1
# 1591  950   OA2
# 1592  950   OX1
# 1593  950   SA1
# 1594  950   SE1
# 1595  950   SF1
# 1596  950   SI1
# 1597  950   SJ2
# 1598  950   SJ3
# 1599  950   SJ4
# 1600  950   SO1
# 1601  950   SO2
# 1602  950   SP1
# 1603  950   SP2
# 1604  950   SU1
#
# [1605 rows x 10 columns]

# %%
from datetime import datetime, timedelta

date = datetime.strptime("2016/12/31", "%Y/%m/%d")
delta = timedelta(days=1)
while(date <= datetime.strptime("2017/01/12", "%Y/%m/%d")):
    print(date)
    date = date + delta
# Out:
# 2016-12-31 00:00:00
# 2017-01-01 00:00:00
# 2017-01-02 00:00:00
# 2017-01-03 00:00:00
# 2017-01-04 00:00:00
# 2017-01-05 00:00:00
# 2017-01-06 00:00:00
# 2017-01-07 00:00:00
# 2017-01-08 00:00:00
# 2017-01-09 00:00:00
# 2017-01-10 00:00:00
# 2017-01-11 00:00:00
# 2017-01-12 00:00:00

# %%
start = datetime.strptime("2016/12/31", "%Y/%m/%d")
start1 = datetime.strptime("2017/01/01", "%Y/%m/%d")
start + delta
# Out:
# datetime.datetime(2017, 1, 1, 0, 0)

# %%
start <= start1
# Out:
# True

# %%
print(start)
# Out:
# 2016-12-31 00:00:00

# %%
start
