# %%
import requests
import json
from bs4 import BeautifulSoup
import re
import concurrent.futures

# %%
DOMAIN = "https://www.pinkoi.com"
style_dict = {"可愛":"cute", "簡約":"minimal", "浪漫":"romantic", "復古":"vintage", "雜貨":"zakka", 
         "中性":"neutral", "民族":"green", "都會":"urban", "禪風":"zen"}

# %%
resp = requests.get("https://www.pinkoi.com/browse")
soup = BeautifulSoup(resp.text, "html5lib")
categories = {category.text.split("\n")[2].strip(): category.get("href") for category in soup.select(".category-list > li > a")}
categories
# Out:
# {'3C · 家電': '/browse?category=11',
#  'DIY 材料': '/browse?category=8',
#  '品味美食': '/browse?category=10',
#  '媽咪寶寶': '/browse?category=4',
#  '寵物用品': '/browse?category=6',
#  '居家良品': '/browse?category=5',
#  '戶外生活': '/browse?category=9',
#  '文具卡片': '/browse?category=3',
#  '衣著良品': '/browse?category=0',
#  '配件飾品': '/browse?category=2',
#  '鞋子包包': '/browse?category=1'}

# %%
subcategories_list = soup.select(".subcategory > li > a")
subcategories = {a.text.split('\n')[1].strip(): a.get("href") for a in subcategories_list if re.match("/browse\?category=\d*&subcategory=\d*", a.get("href"))}
subcategories
# Out:
# {'Android 週邊': '/browse?category=11&subcategory=1102',
#  'DIY 材料包': '/browse?category=8&subcategory=803',
#  'USB 隨身碟': '/browse?category=11&subcategory=1105',
#  'iPhone 週邊': '/browse?category=11&subcategory=1101',
#  '中性連帽外套/T 恤': '/browse?category=0&subcategory=15',
#  '中性針織衫/毛衣': '/browse?category=0&subcategory=21',
#  '串珠材料': '/browse?category=8&subcategory=801',
#  '乾貨': '/browse?category=10&subcategory=1014',
#  '便條紙/標籤貼': '/browse?category=3&subcategory=321',
#  '兒童家具': '/browse?category=4&subcategory=403',
#  '內衣褲': '/browse?category=0&subcategory=22',
#  '公事包': '/browse?category=1&subcategory=112',
#  '其他': '/browse?category=9&subcategory=999',
#  '冰淇淋/冰棒': '/browse?category=10&subcategory=1009',
#  '刊物/書籍': '/browse?category=3&subcategory=313',
#  '包裝材料': '/browse?category=8&subcategory=806',
#  '化妝包/雜物包': '/browse?category=1&subcategory=113',
#  '卡片/明信片': '/browse?category=3&subcategory=304',
#  '印章/印台': '/browse?category=3&subcategory=312',
#  '吊帶褲': '/browse?category=0&subcategory=13',
#  '吊飾': '/browse?category=3&subcategory=314',
#  '名片夾/名片盒': '/browse?category=2&subcategory=219',
#  '咖啡': '/browse?category=10&subcategory=1018',
#  '咖啡杯/馬克杯': '/browse?category=5&subcategory=505',
#  '圍兜/口水巾': '/browse?category=4&subcategory=405',
#  '圍裙': '/browse?category=5&subcategory=520',
#  '地圖': '/browse?category=9&subcategory=903',
#  '女裝 T 恤': '/browse?category=0&subcategory=1',
#  '女裝上衣': '/browse?category=0&subcategory=11',
#  '女裝外套': '/browse?category=0&subcategory=7',
#  '女裝背心': '/browse?category=0&subcategory=2',
#  '女裝褲子': '/browse?category=0&subcategory=4',
#  '女裝襯衫': '/browse?category=0&subcategory=9',
#  '女裝針織衫/毛衣': '/browse?category=0&subcategory=8',
#  '女錶': '/browse?category=2&subcategory=215',
#  '女鞋': '/browse?category=1&subcategory=101',
#  '媽媽包': '/browse?category=4&subcategory=406',
#  '存錢筒': '/browse?category=5&subcategory=536',
#  '客製畫像': '/browse?category=5&subcategory=538',
#  '家具': '/browse?category=5&subcategory=521',
#  '寢具': '/browse?category=5&subcategory=527',
#  '巧克力': '/browse?category=10&subcategory=1022',
#  '帽子': '/browse?category=2&subcategory=208',
#  '平板/電腦保護殼': '/browse?category=11&subcategory=1108',
#  '年曆/桌曆': '/browse?category=3&subcategory=320',
#  '床墊/籠': '/browse?category=6&subcategory=603',
#  '廚房用具': '/browse?category=5&subcategory=533',
#  '彌月禮盒': '/browse?category=4&subcategory=412',
#  '後背包': '/browse?category=1&subcategory=111',
#  '徽章/別針': '/browse?category=3&subcategory=315',
#  '戒指': '/browse?category=2&subcategory=202',
#  '手套': '/browse?category=2&subcategory=209',
#  '手工餅乾': '/browse?category=10&subcategory=1010',
#  '手提包': '/browse?category=1&subcategory=105',
#  '手鍊/手環': '/browse?category=2&subcategory=205',
#  '捲線器/電線收納': '/browse?category=11&subcategory=1106',
#  '擴音器/喇叭': '/browse?category=11&subcategory=1111',
#  '擺飾': '/browse?category=5&subcategory=506',
#  '攝影集': '/browse?category=3&subcategory=307',
#  '收納用品': '/browse?category=5&subcategory=532',
#  '文件夾/資料夾': '/browse?category=3&subcategory=309',
#  '料理包': '/browse?category=10&subcategory=1021',
#  '時鐘/鬧鐘': '/browse?category=5&subcategory=512',
#  '晚宴包/手拿包': '/browse?category=1&subcategory=108',
#  '書籤': '/browse?category=3&subcategory=323',
#  '束口後背包': '/browse?category=1&subcategory=114',
#  '杯墊': '/browse?category=5&subcategory=504',
#  '杯子蛋糕': '/browse?category=10&subcategory=1008',
#  '枕頭/抱枕': '/browse?category=5&subcategory=525',
#  '果醬/抹醬': '/browse?category=10&subcategory=1003',
#  '植栽/盆栽': '/browse?category=5&subcategory=508',
#  '樂器': '/browse?category=5&subcategory=537',
#  '毛巾/浴巾': '/browse?category=5&subcategory=518',
#  '水壺': '/browse?category=9&subcategory=904',
#  '水果乾': '/browse?category=10&subcategory=1013',
#  '洋裝/連身裙': '/browse?category=0&subcategory=6',
#  '海報/畫作/版畫': '/browse?category=5&subcategory=517',
#  '淺碟/小碟': '/browse?category=5&subcategory=530',
#  '清潔/美容': '/browse?category=6&subcategory=606',
#  '清潔保養': '/browse?category=5&subcategory=519',
#  '燈具/燈飾': '/browse?category=5&subcategory=501',
#  '牆貼/壁貼': '/browse?category=5&subcategory=507',
#  '版畫': '/browse?category=5&subcategory=515',
#  '獨立音樂': '/browse?category=5&subcategory=522',
#  '玩偶/公仔': '/browse?category=5&subcategory=510',
#  '玩具': '/browse?category=6&subcategory=602',
#  '玩具/玩偶': '/browse?category=4&subcategory=404',
#  '男裝上衣/T 恤': '/browse?category=0&subcategory=16',
#  '男裝外套': '/browse?category=0&subcategory=20',
#  '男裝背心': '/browse?category=0&subcategory=17',
#  '男裝褲子': '/browse?category=0&subcategory=19',
#  '男裝襯衫': '/browse?category=0&subcategory=18',
#  '男鞋': '/browse?category=1&subcategory=102',
#  '畫作': '/browse?category=5&subcategory=523',
#  '畫框/相框': '/browse?category=5&subcategory=524',
#  '皮夾/錢包': '/browse?category=1&subcategory=103',
#  '皮箱': '/browse?category=1&subcategory=117',
#  '相機': '/browse?category=11&subcategory=1110',
#  '相機包': '/browse?category=1&subcategory=110',
#  '相簿/相本': '/browse?category=3&subcategory=308',
#  '眼罩/口罩': '/browse?category=2&subcategory=226',
#  '眼鏡/眼鏡框': '/browse?category=2&subcategory=216',
#  '碗': '/browse?category=5&subcategory=531',
#  '碗/碗架': '/browse?category=6&subcategory=608',
#  '磁鐵': '/browse?category=3&subcategory=318',
#  '童裝': '/browse?category=4&subcategory=402',
#  '童鞋': '/browse?category=4&subcategory=409',
#  '筆': '/browse?category=3&subcategory=317',
#  '筆盒/筆袋': '/browse?category=3&subcategory=303',
#  '筆筒/筆座': '/browse?category=3&subcategory=306',
#  '筆記本/手帳': '/browse?category=3&subcategory=301',
#  '筷子/筷架': '/browse?category=5&subcategory=528',
#  '米/米粉/麵線': '/browse?category=10&subcategory=1019',
#  '糖果/軟糖': '/browse?category=10&subcategory=1005',
#  '紅包/春聯': '/browse?category=3&subcategory=322',
#  '紋身貼紙': '/browse?category=2&subcategory=224',
#  '紙張材料': '/browse?category=8&subcategory=804',
#  '紙膠帶': '/browse?category=3&subcategory=310',
#  '絲巾': '/browse?category=2&subcategory=207',
#  '線材/綁材': '/browse?category=8&subcategory=805',
#  '罩衫': '/browse?category=0&subcategory=14',
#  '耳機': '/browse?category=11&subcategory=1107',
#  '耳環/耳夾': '/browse?category=2&subcategory=203',
#  '肥皂/手工皂': '/browse?category=5&subcategory=539',
#  '肩背包/斜背包': '/browse?category=1&subcategory=104',
#  '胸針': '/browse?category=2&subcategory=210',
#  '腰帶/皮帶': '/browse?category=2&subcategory=225',
#  '腳踏車/周邊': '/browse?category=9&subcategory=901',
#  '花瓶/陶器': '/browse?category=5&subcategory=509',
#  '茶': '/browse?category=10&subcategory=1002',
#  '茶具/茶杯': '/browse?category=5&subcategory=511',
#  '蛋糕/甜點': '/browse?category=10&subcategory=1001',
#  '蜂蜜/黑糖': '/browse?category=10&subcategory=1004',
#  '蠟燭/燭台': '/browse?category=5&subcategory=516',
#  '行動電源/傳輸線': '/browse?category=11&subcategory=1113',
#  '行李吊牌': '/browse?category=3&subcategory=311',
#  '衣/帽': '/browse?category=6&subcategory=607',
#  '袖扣': '/browse?category=2&subcategory=213',
#  '被子/毛毯': '/browse?category=5&subcategory=526',
#  '裙子': '/browse?category=0&subcategory=3',
#  '襪子': '/browse?category=0&subcategory=10',
#  '觸控筆': '/browse?category=11&subcategory=1109',
#  '調味罐/醬料罐': '/browse?category=5&subcategory=535',
#  '證件套/卡套': '/browse?category=2&subcategory=220',
#  '護照夾/護照套': '/browse?category=2&subcategory=218',
#  '貼紙': '/browse?category=3&subcategory=305',
#  '連身褲': '/browse?category=0&subcategory=12',
#  '醬料/調味料': '/browse?category=10&subcategory=1020',
#  '野餐墊/露營用品': '/browse?category=9&subcategory=905',
#  '釘書機': '/browse?category=3&subcategory=316',
#  '鏡子/梳子/美妝工具': '/browse?category=2&subcategory=227',
#  '鑰匙圈/鑰匙包': '/browse?category=2&subcategory=217',
#  '隨行杯提袋/護套': '/browse?category=5&subcategory=514',
#  '雨傘/雨衣': '/browse?category=9&subcategory=902',
#  '零錢包': '/browse?category=1&subcategory=106',
#  '電腦包': '/browse?category=1&subcategory=109',
#  '電話/話筒': '/browse?category=11&subcategory=1112',
#  '項圈/牽繩': '/browse?category=6&subcategory=604',
#  '項鍊': '/browse?category=2&subcategory=201',
#  '領結/領帶': '/browse?category=2&subcategory=222',
#  '飼料/罐頭': '/browse?category=6&subcategory=605',
#  '餐刀/叉/匙組合': '/browse?category=5&subcategory=529',
#  '餐墊/桌巾': '/browse?category=5&subcategory=534',
#  '香氛/精油/薰香': '/browse?category=5&subcategory=503',
#  '髮飾': '/browse?category=2&subcategory=204',
#  '鹹派': '/browse?category=10&subcategory=1012',
#  '鹹派/甜派': '/browse?category=10&subcategory=1007',
#  '麵包/吐司': '/browse?category=10&subcategory=1016'}

# %%
# combine categories and subcategories to dictionary of dictionary

product = {}

for index, value in categories.items():
    number = re.findall("\?category=(\d+)", value)
    temp = {}
    for i, v in subcategories.items():
        if re.findall("\?category=(\d+)", v) == number:
            temp[i] = v
    product[index] = temp
product
# Out:
# {'3C · 家電': {'Android 週邊': '/browse?category=11&subcategory=1102',
#   'USB 隨身碟': '/browse?category=11&subcategory=1105',
#   'iPhone 週邊': '/browse?category=11&subcategory=1101',
#   '平板/電腦保護殼': '/browse?category=11&subcategory=1108',
#   '捲線器/電線收納': '/browse?category=11&subcategory=1106',
#   '擴音器/喇叭': '/browse?category=11&subcategory=1111',
#   '相機': '/browse?category=11&subcategory=1110',
#   '耳機': '/browse?category=11&subcategory=1107',
#   '行動電源/傳輸線': '/browse?category=11&subcategory=1113',
#   '觸控筆': '/browse?category=11&subcategory=1109',
#   '電話/話筒': '/browse?category=11&subcategory=1112'},
#  'DIY 材料': {'DIY 材料包': '/browse?category=8&subcategory=803',
#   '串珠材料': '/browse?category=8&subcategory=801',
#   '包裝材料': '/browse?category=8&subcategory=806',
#   '紙張材料': '/browse?category=8&subcategory=804',
#   '線材/綁材': '/browse?category=8&subcategory=805'},
#  '品味美食': {'乾貨': '/browse?category=10&subcategory=1014',
#   '冰淇淋/冰棒': '/browse?category=10&subcategory=1009',
#   '咖啡': '/browse?category=10&subcategory=1018',
#   '巧克力': '/browse?category=10&subcategory=1022',
#   '手工餅乾': '/browse?category=10&subcategory=1010',
#   '料理包': '/browse?category=10&subcategory=1021',
#   '杯子蛋糕': '/browse?category=10&subcategory=1008',
#   '果醬/抹醬': '/browse?category=10&subcategory=1003',
#   '水果乾': '/browse?category=10&subcategory=1013',
#   '米/米粉/麵線': '/browse?category=10&subcategory=1019',
#   '糖果/軟糖': '/browse?category=10&subcategory=1005',
#   '茶': '/browse?category=10&subcategory=1002',
#   '蛋糕/甜點': '/browse?category=10&subcategory=1001',
#   '蜂蜜/黑糖': '/browse?category=10&subcategory=1004',
#   '醬料/調味料': '/browse?category=10&subcategory=1020',
#   '鹹派': '/browse?category=10&subcategory=1012',
#   '鹹派/甜派': '/browse?category=10&subcategory=1007',
#   '麵包/吐司': '/browse?category=10&subcategory=1016'},
#  '媽咪寶寶': {'兒童家具': '/browse?category=4&subcategory=403',
#   '圍兜/口水巾': '/browse?category=4&subcategory=405',
#   '媽媽包': '/browse?category=4&subcategory=406',
#   '彌月禮盒': '/browse?category=4&subcategory=412',
#   '玩具/玩偶': '/browse?category=4&subcategory=404',
#   '童裝': '/browse?category=4&subcategory=402',
#   '童鞋': '/browse?category=4&subcategory=409'},
#  '寵物用品': {'床墊/籠': '/browse?category=6&subcategory=603',
#   '清潔/美容': '/browse?category=6&subcategory=606',
#   '玩具': '/browse?category=6&subcategory=602',
#   '碗/碗架': '/browse?category=6&subcategory=608',
#   '衣/帽': '/browse?category=6&subcategory=607',
#   '項圈/牽繩': '/browse?category=6&subcategory=604',
#   '飼料/罐頭': '/browse?category=6&subcategory=605'},
#  '居家良品': {'咖啡杯/馬克杯': '/browse?category=5&subcategory=505',
#   '圍裙': '/browse?category=5&subcategory=520',
#   '存錢筒': '/browse?category=5&subcategory=536',
#   '客製畫像': '/browse?category=5&subcategory=538',
#   '家具': '/browse?category=5&subcategory=521',
#   '寢具': '/browse?category=5&subcategory=527',
#   '廚房用具': '/browse?category=5&subcategory=533',
#   '擺飾': '/browse?category=5&subcategory=506',
#   '收納用品': '/browse?category=5&subcategory=532',
#   '時鐘/鬧鐘': '/browse?category=5&subcategory=512',
#   '杯墊': '/browse?category=5&subcategory=504',
#   '枕頭/抱枕': '/browse?category=5&subcategory=525',
#   '植栽/盆栽': '/browse?category=5&subcategory=508',
#   '樂器': '/browse?category=5&subcategory=537',
#   '毛巾/浴巾': '/browse?category=5&subcategory=518',
#   '海報/畫作/版畫': '/browse?category=5&subcategory=517',
#   '淺碟/小碟': '/browse?category=5&subcategory=530',
#   '清潔保養': '/browse?category=5&subcategory=519',
#   '燈具/燈飾': '/browse?category=5&subcategory=501',
#   '牆貼/壁貼': '/browse?category=5&subcategory=507',
#   '版畫': '/browse?category=5&subcategory=515',
#   '獨立音樂': '/browse?category=5&subcategory=522',
#   '玩偶/公仔': '/browse?category=5&subcategory=510',
#   '畫作': '/browse?category=5&subcategory=523',
#   '畫框/相框': '/browse?category=5&subcategory=524',
#   '碗': '/browse?category=5&subcategory=531',
#   '筷子/筷架': '/browse?category=5&subcategory=528',
#   '肥皂/手工皂': '/browse?category=5&subcategory=539',
#   '花瓶/陶器': '/browse?category=5&subcategory=509',
#   '茶具/茶杯': '/browse?category=5&subcategory=511',
#   '蠟燭/燭台': '/browse?category=5&subcategory=516',
#   '被子/毛毯': '/browse?category=5&subcategory=526',
#   '調味罐/醬料罐': '/browse?category=5&subcategory=535',
#   '隨行杯提袋/護套': '/browse?category=5&subcategory=514',
#   '餐刀/叉/匙組合': '/browse?category=5&subcategory=529',
#   '餐墊/桌巾': '/browse?category=5&subcategory=534',
#   '香氛/精油/薰香': '/browse?category=5&subcategory=503'},
#  '戶外生活': {'其他': '/browse?category=9&subcategory=999',
#   '地圖': '/browse?category=9&subcategory=903',
#   '水壺': '/browse?category=9&subcategory=904',
#   '腳踏車/周邊': '/browse?category=9&subcategory=901',
#   '野餐墊/露營用品': '/browse?category=9&subcategory=905',
#   '雨傘/雨衣': '/browse?category=9&subcategory=902'},
#  '文具卡片': {'便條紙/標籤貼': '/browse?category=3&subcategory=321',
#   '刊物/書籍': '/browse?category=3&subcategory=313',
#   '卡片/明信片': '/browse?category=3&subcategory=304',
#   '印章/印台': '/browse?category=3&subcategory=312',
#   '吊飾': '/browse?category=3&subcategory=314',
#   '年曆/桌曆': '/browse?category=3&subcategory=320',
#   '徽章/別針': '/browse?category=3&subcategory=315',
#   '攝影集': '/browse?category=3&subcategory=307',
#   '文件夾/資料夾': '/browse?category=3&subcategory=309',
#   '書籤': '/browse?category=3&subcategory=323',
#   '相簿/相本': '/browse?category=3&subcategory=308',
#   '磁鐵': '/browse?category=3&subcategory=318',
#   '筆': '/browse?category=3&subcategory=317',
#   '筆盒/筆袋': '/browse?category=3&subcategory=303',
#   '筆筒/筆座': '/browse?category=3&subcategory=306',
#   '筆記本/手帳': '/browse?category=3&subcategory=301',
#   '紅包/春聯': '/browse?category=3&subcategory=322',
#   '紙膠帶': '/browse?category=3&subcategory=310',
#   '行李吊牌': '/browse?category=3&subcategory=311',
#   '貼紙': '/browse?category=3&subcategory=305',
#   '釘書機': '/browse?category=3&subcategory=316'},
#  '衣著良品': {'中性連帽外套/T 恤': '/browse?category=0&subcategory=15',
#   '中性針織衫/毛衣': '/browse?category=0&subcategory=21',
#   '內衣褲': '/browse?category=0&subcategory=22',
#   '吊帶褲': '/browse?category=0&subcategory=13',
#   '女裝 T 恤': '/browse?category=0&subcategory=1',
#   '女裝上衣': '/browse?category=0&subcategory=11',
#   '女裝外套': '/browse?category=0&subcategory=7',
#   '女裝背心': '/browse?category=0&subcategory=2',
#   '女裝褲子': '/browse?category=0&subcategory=4',
#   '女裝襯衫': '/browse?category=0&subcategory=9',
#   '女裝針織衫/毛衣': '/browse?category=0&subcategory=8',
#   '洋裝/連身裙': '/browse?category=0&subcategory=6',
#   '男裝上衣/T 恤': '/browse?category=0&subcategory=16',
#   '男裝外套': '/browse?category=0&subcategory=20',
#   '男裝背心': '/browse?category=0&subcategory=17',
#   '男裝褲子': '/browse?category=0&subcategory=19',
#   '男裝襯衫': '/browse?category=0&subcategory=18',
#   '罩衫': '/browse?category=0&subcategory=14',
#   '裙子': '/browse?category=0&subcategory=3',
#   '襪子': '/browse?category=0&subcategory=10',
#   '連身褲': '/browse?category=0&subcategory=12'},
#  '配件飾品': {'名片夾/名片盒': '/browse?category=2&subcategory=219',
#   '女錶': '/browse?category=2&subcategory=215',
#   '帽子': '/browse?category=2&subcategory=208',
#   '戒指': '/browse?category=2&subcategory=202',
#   '手套': '/browse?category=2&subcategory=209',
#   '手鍊/手環': '/browse?category=2&subcategory=205',
#   '眼罩/口罩': '/browse?category=2&subcategory=226',
#   '眼鏡/眼鏡框': '/browse?category=2&subcategory=216',
#   '紋身貼紙': '/browse?category=2&subcategory=224',
#   '絲巾': '/browse?category=2&subcategory=207',
#   '耳環/耳夾': '/browse?category=2&subcategory=203',
#   '胸針': '/browse?category=2&subcategory=210',
#   '腰帶/皮帶': '/browse?category=2&subcategory=225',
#   '袖扣': '/browse?category=2&subcategory=213',
#   '證件套/卡套': '/browse?category=2&subcategory=220',
#   '護照夾/護照套': '/browse?category=2&subcategory=218',
#   '鏡子/梳子/美妝工具': '/browse?category=2&subcategory=227',
#   '鑰匙圈/鑰匙包': '/browse?category=2&subcategory=217',
#   '項鍊': '/browse?category=2&subcategory=201',
#   '領結/領帶': '/browse?category=2&subcategory=222',
#   '髮飾': '/browse?category=2&subcategory=204'},
#  '鞋子包包': {'公事包': '/browse?category=1&subcategory=112',
#   '化妝包/雜物包': '/browse?category=1&subcategory=113',
#   '女鞋': '/browse?category=1&subcategory=101',
#   '後背包': '/browse?category=1&subcategory=111',
#   '手提包': '/browse?category=1&subcategory=105',
#   '晚宴包/手拿包': '/browse?category=1&subcategory=108',
#   '束口後背包': '/browse?category=1&subcategory=114',
#   '男鞋': '/browse?category=1&subcategory=102',
#   '皮夾/錢包': '/browse?category=1&subcategory=103',
#   '皮箱': '/browse?category=1&subcategory=117',
#   '相機包': '/browse?category=1&subcategory=110',
#   '肩背包/斜背包': '/browse?category=1&subcategory=104',
#   '零錢包': '/browse?category=1&subcategory=106',
#   '電腦包': '/browse?category=1&subcategory=109'}}

# %%
def save_to_csv(urls, category, subcategory, style):
    jd = json.dumps(urls)
    with open("./pinkoi/category{}_subcategory{}_{}.csv".format(category, subcategory, style), "w") as f:
        f.write(jd)

# %%
def get_url(URL):
    category = re.findall("\?category=(\d+)", URL)
    subcategory = re.findall("&subcategory=(\d+)", URL)
    style = re.findall("&style=(\w+)", URL)
    switch = True
    counter = 1
    urls = []
    URL = DOMAIN + URL + "&page={}"
    while switch:
        resp = requests.get(URL.format(counter))
        soup = BeautifulSoup(resp.text, "html5lib")
        urls_temp = [a.get("href").split("?")[0] for a in soup.select(".items.clr > div > a")]
        urls.extend(urls_temp)
        verify = soup.select(".g_pagination > a")[-1].text == "下一頁 ►"
        if not verify:
            switch = False
        counter += 1
    save_to_csv(urls, category, subcategory, style)

# %%
def main():
    with concurrent.futures.ThreadPoolExecutor(max_workers=50) as executor:
        for subtitle in product.values():
            for url in subtitle.values():
                for style in style_dict.values():
                    executor.submit(get_url(url+"&style={}".format(style)))

# %%
if __name__=="__main__":
    main()

# %%
# Out:
# /browse?category=2&subcategory=205
# /browse?category=2&subcategory=203
# /browse?category=2&subcategory=201
# /browse?category=2&subcategory=202
# /browse?category=2&subcategory=204
# /browse?category=2&subcategory=217
# /browse?category=2&subcategory=208
# /browse?category=2&subcategory=207
# /browse?category=2&subcategory=210
# /browse?category=2&subcategory=215
# /browse?category=2&subcategory=220
# /browse?category=2&subcategory=218
# /browse?category=2&subcategory=219
# /browse?category=2&subcategory=224
# /browse?category=2&subcategory=216
# /browse?category=2&subcategory=222
# /browse?category=2&subcategory=226
# /browse?category=2&subcategory=227
# /browse?category=2&subcategory=209
# /browse?category=2&subcategory=225
# /browse?category=2&subcategory=213
# /browse?category=5&subcategory=508
# /browse?category=5&subcategory=506
# /browse?category=5&subcategory=505
# /browse?category=5&subcategory=511
# /browse?category=5&subcategory=528
# /browse?category=5&subcategory=520
# /browse?category=5&subcategory=539
# /browse?category=5&subcategory=519
# /browse?category=5&subcategory=532
# /browse?category=5&subcategory=514
# /browse?category=5&subcategory=503
# /browse?category=5&subcategory=512
# /browse?category=5&subcategory=501
# /browse?category=5&subcategory=525
# /browse?category=5&subcategory=504
# /browse?category=5&subcategory=538
# /browse?category=5&subcategory=507
# /browse?category=5&subcategory=510
# /browse?category=5&subcategory=530
# /browse?category=5&subcategory=516
# /browse?category=5&subcategory=518
# /browse?category=5&subcategory=533
# /browse?category=5&subcategory=529
# /browse?category=5&subcategory=531
# /browse?category=5&subcategory=534
# /browse?category=5&subcategory=521
# /browse?category=5&subcategory=509
# /browse?category=5&subcategory=524
# /browse?category=5&subcategory=527
# /browse?category=5&subcategory=536
# /browse?category=5&subcategory=526
# /browse?category=5&subcategory=537
# /browse?category=5&subcategory=515
# /browse?category=5&subcategory=517
# /browse?category=5&subcategory=523
# /browse?category=5&subcategory=535
# /browse?category=5&subcategory=522
# /browse?category=3&subcategory=304
# /browse?category=3&subcategory=305
# /browse?category=3&subcategory=301
# /browse?category=3&subcategory=310
# /browse?category=3&subcategory=303
# /browse?category=3&subcategory=306
# /browse?category=3&subcategory=317
# /browse?category=3&subcategory=315
# /browse?category=3&subcategory=312
# /browse?category=3&subcategory=309
# /browse?category=3&subcategory=311
# /browse?category=3&subcategory=314
# /browse?category=3&subcategory=323
# /browse?category=3&subcategory=321
# /browse?category=3&subcategory=308
# /browse?category=3&subcategory=318
# /browse?category=3&subcategory=316
# /browse?category=3&subcategory=307
# /browse?category=3&subcategory=313
# /browse?category=3&subcategory=320
# /browse?category=3&subcategory=322
# /browse?category=1&subcategory=101
# /browse?category=1&subcategory=102
# /browse?category=1&subcategory=104
# /browse?category=1&subcategory=111
# /browse?category=1&subcategory=103
# /browse?category=1&subcategory=105
# /browse?category=1&subcategory=106
# /browse?category=1&subcategory=113
# /browse?category=1&subcategory=109
# /browse?category=1&subcategory=114
# /browse?category=1&subcategory=112
# /browse?category=1&subcategory=108
# /browse?category=1&subcategory=110
# /browse?category=1&subcategory=117
# /browse?category=0&subcategory=6
# /browse?category=0&subcategory=11
# /browse?category=0&subcategory=4
# /browse?category=0&subcategory=1
# /browse?category=0&subcategory=9
# /browse?category=0&subcategory=3
# /browse?category=0&subcategory=7
# /browse?category=0&subcategory=2
# /browse?category=0&subcategory=8
# /browse?category=0&subcategory=15
# /browse?category=0&subcategory=21
# /browse?category=0&subcategory=13
# /browse?category=0&subcategory=12
# /browse?category=0&subcategory=10
# /browse?category=0&subcategory=16
# /browse?category=0&subcategory=19
# /browse?category=0&subcategory=18
# /browse?category=0&subcategory=20
# /browse?category=0&subcategory=17
# /browse?category=0&subcategory=14
# /browse?category=0&subcategory=22
# /browse?category=11&subcategory=1101
# /browse?category=11&subcategory=1102
# /browse?category=11&subcategory=1108
# /browse?category=11&subcategory=1106
# /browse?category=11&subcategory=1107
# /browse?category=11&subcategory=1110
# /browse?category=11&subcategory=1111
# /browse?category=11&subcategory=1113
# /browse?category=11&subcategory=1105
# /browse?category=11&subcategory=1109
# /browse?category=11&subcategory=1112
# /browse?category=4&subcategory=405
# /browse?category=4&subcategory=412
# /browse?category=4&subcategory=406
# /browse?category=4&subcategory=402
# /browse?category=4&subcategory=404
# /browse?category=4&subcategory=409
# /browse?category=4&subcategory=403
# /browse?category=10&subcategory=1002
# /browse?category=10&subcategory=1013
# /browse?category=10&subcategory=1007
# /browse?category=10&subcategory=1001
# /browse?category=10&subcategory=1010
# /browse?category=10&subcategory=1003
# /browse?category=10&subcategory=1005
# /browse?category=10&subcategory=1004
# /browse?category=10&subcategory=1022
# /browse?category=10&subcategory=1018
# /browse?category=10&subcategory=1019
# /browse?category=10&subcategory=1014
# /browse?category=10&subcategory=1021
# /browse?category=10&subcategory=1020
# /browse?category=10&subcategory=1012
# /browse?category=10&subcategory=1016
# /browse?category=10&subcategory=1008
# /browse?category=10&subcategory=1009
# /browse?category=8&subcategory=803
# /browse?category=8&subcategory=806
# /browse?category=8&subcategory=804
# /browse?category=8&subcategory=801
# /browse?category=8&subcategory=805
# /browse?category=6&subcategory=604
# /browse?category=6&subcategory=607
# /browse?category=6&subcategory=608
# /browse?category=6&subcategory=605
# /browse?category=6&subcategory=606
# /browse?category=6&subcategory=602
# /browse?category=6&subcategory=603
# /browse?category=9&subcategory=999
# /browse?category=9&subcategory=904
# /browse?category=9&subcategory=902
# /browse?category=9&subcategory=905
# /browse?category=9&subcategory=901
# /browse?category=9&subcategory=903

# %%
#test get_url function using https://www.pinkoi.com/browse/?_currency=TWD&category=2&price=5000&subcategory=205&page={}

x = get_url()
x
# Out:
# ['/product/FexVsD5R',
#  '/product/MjPQMUqW',
#  '/product/EmTG7m8W',
#  '/product/YA54cCwq',
#  '/product/4Qufk5h3',
#  '/product/cDiNXqJ9',
#  '/product/4BPRZEtY',
#  '/product/2KuhjXVq',
#  '/product/7Ae5v3Ws',
#  '/product/1J5bl08T',
#  '/product/n4Yr58rC',
#  '/product/JPAPEZaf',
#  '/product/6uRirWKt',
#  '/product/sYczCvwH',
#  '/product/CNjW9DZE',
#  '/product/JP4Rc2fj',
#  '/product/1ncgATbK',
#  '/product/1a3Z0wR1',
#  '/product/mXhLgkkt',
#  '/product/eRZmqRFp',
#  '/product/Yt8veLeq',
#  '/product/NYN7FMVx',
#  '/product/1VpBFAvu',
#  '/product/1XZgXxKO',
#  '/product/i9nECvET',
#  '/product/1eAwrHJh',
#  '/product/buy72Qrn',
#  '/product/1qBQ8Ksx',
#  '/product/1SJnVQUY',
#  '/product/1kYThNz9',
#  '/product/A5GpEdUP',
#  '/product/ugeLcSEW',
#  '/product/2Bjf6rtX',
#  '/product/1XBoneXB',
#  '/product/Zgn8Lb4V',
#  '/product/xZNf5Tmq',
#  '/product/1tghsdSj',
#  '/product/RgSyzCjk',
#  '/product/xQupV6Ny',
#  '/product/W7bga4i6',
#  '/product/1_xKfy7R',
#  '/product/gPAtBYKc',
#  '/product/bxy2q6Th',
#  '/product/FWbNG5A7',
#  '/product/1befBioW',
#  '/product/fFRXb5ab',
#  '/product/15BUbfLk',
#  '/product/qCDQQHGz',
#  '/product/GvLhSJyg',
#  '/product/jvuaDTUe',
#  '/product/8VWpt2zd',
#  '/product/Ap5f4keP',
#  '/product/N45givTi',
#  '/product/pvNSUQLF',
#  '/product/Ndt6JtKZ',
#  '/product/CxxKkbi2',
#  '/product/EtEhbiGd',
#  '/product/cZmEGn5g',
#  '/product/oSKWf0DQ',
#  '/product/6Pz6xdVS',
#  '/product/1dPXXe37',
#  '/product/hVL5CeHF',
#  '/product/bKvPqdUb',
#  '/product/18ByS3XA',
#  '/product/1nxYuVJb',
#  '/product/1d5URuFs',
#  '/product/EPLA645S',
#  '/product/2duUcYJ9',
#  '/product/14ymRTBS',
#  '/product/1yRhYOlI',
#  '/product/6xPq9tem',
#  '/product/1kuixz48',
#  '/product/DELzqdDB',
#  '/product/1U8yWRxc',
#  '/product/9vyzRTE2',
#  '/product/uaHTKckd',
#  '/product/E3Zf3YRp',
#  '/product/wkKWYexb',
#  '/product/uzMXQUkf',
#  '/product/1H4eHTA7',
#  '/product/Qd67gU8Y',
#  '/product/Cxep2iCB',
#  '/product/15vw8X8L',
#  '/product/1qYZhSRb',
#  '/product/HhYWIn1y',
#  '/product/a1UCnjKL',
#  '/product/RcEEgP3r',
#  '/product/WwXMRNG5',
#  '/product/1ThH0KaI',
#  '/product/RqC8SLhd',
#  '/product/sYCa2b7u',
#  '/product/KBsV6jhZ',
#  '/product/ikdszCjY',
#  '/product/1PCjbD54',
#  '/product/1RkMgmp7',
#  '/product/TK7PgHUC',
#  '/product/kLtsqry3',
#  '/product/1ss2rBuz',
#  '/product/cZLSHepG',
#  '/product/1llKWl51',
#  '/product/nuTHk3w3',
#  '/product/1uWmWmUf',
#  '/product/1hSH6mps',
#  '/product/HY7tTpnv',
#  '/product/GvlYu6Of',
#  '/product/tsug8XpY',
#  '/product/G4n5wHNT',
#  '/product/mSsW7ziF',
#  '/product/8K4sdD8b',
#  '/product/90ukZbo7',
#  '/product/m63CYUmZ',
#  '/product/5urLJsNy',
#  '/product/VxSUuHLV',
#  '/product/1sj3Q68i',
#  '/product/HWCkM01n',
#  '/product/sdsqYMVX',
#  '/product/iyceTnp6',
#  '/product/NP8ARLkh',
#  '/product/pWSG9dgT',
#  '/product/1tX8FrOa',
#  '/product/PHWMmaB3',
#  '/product/MNqnyi6A',
#  '/product/XMDLLS4m',
#  '/product/zuUQVejf',
#  '/product/W9Jm3aUk',
#  '/product/1z9inDE2',
#  '/product/U7zZMVqF',
#  '/product/msfNgvzb',
#  '/product/KmCx5VrH',
#  '/product/iMeHD9zD',
#  '/product/NpH7J9kA',
#  '/product/dnYcqr4r',
#  '/product/2pFQKXr9',
#  '/product/NH27TqhX',
#  '/product/sPRBdHJz',
#  '/product/KXN77CeM',
#  '/product/WNqLmRw6',
#  '/product/qaw5W3mm',
#  '/product/NKamrCxn',
#  '/product/mkN3GmuS',
#  '/product/SH3YHK7C',
#  '/product/5qaJnEJ4',
#  '/product/DzBbAyme',
#  '/product/huRQLftZ',
#  '/product/1FCM5X73',
#  '/product/p7XYNWFL',
#  '/product/vEigqGbV',
#  '/product/16nbZaJR',
#  '/product/kmA276Dp',
#  '/product/N4nsETV9',
#  '/product/gGwGH84k',
#  '/product/iPi5rqtW',
#  '/product/f7JUBtkY',
#  '/product/L4nphULa',
#  '/product/EUeNY9Kn',
#  '/product/E9bsP2kB',
#  '/product/DQxcAJkf',
#  '/product/cNwjdvGa',
#  '/product/DuctTNNT',
#  '/product/9P6tXJRF',
#  '/product/bqE6EFd1',
#  '/product/ZDLQKa6E',
#  '/product/2s5GZN6b',
#  '/product/Nt2oMfQ6',
#  '/product/XSa8QAjV',
#  '/product/krkbbjpm',
#  '/product/tVuMhCiE',
#  '/product/fLRuJgYm',
#  '/product/6GkbucmY',
#  '/product/1FxeH7Re',
#  '/product/nlFA0OlR',
#  '/product/VSEyT8rB',
#  '/product/1CLI61dN',
#  '/product/1zAGMb9o',
#  '/product/1KYbyD6m',
#  '/product/jkVMFqfs',
#  '/product/zHMFvUWb',
#  '/product/RHLW5AeG',
#  '/product/iW3mwF4x',
#  '/product/1jnOSDnr',
#  '/product/Y8TR3VUq',
#  '/product/162h3hHF',
#  '/product/AG9SzC4y',
#  '/product/1KPh05rR',
#  '/product/1dOImbpj',
#  '/product/wKYZJZdB',
#  '/product/1hGhLvzf',
#  '/product/1wcp0eUK',
#  '/product/1j9fgqGK',
#  '/product/Q74eqVRr',
#  '/product/3jPtZRC0',
#  '/product/JwZLL7rd',
#  '/product/zV98DGV2',
#  '/product/JxJC36XK',
#  '/product/8KBickUt',
#  '/product/EQnFSZsC',
#  '/product/svNPrhFC',
#  '/product/mLgsLdvu',
#  '/product/NWkrDhf8',
#  '/product/HFk5CGdW',
#  '/product/6XDMuHWW',
#  '/product/6AfdYHma',
#  '/product/rBmLwEK4',
#  '/product/Lvkwxbbn',
#  '/product/ZVAEPDz2',
#  '/product/qfrwppG2',
#  '/product/uQnn4tU7',
#  '/product/1fFpuwXN',
#  '/product/DEgPUbXE',
#  '/product/SAazHFzL',
#  '/product/PChbJUxd',
#  '/product/L4FVL3Wf',
#  '/product/VeZ9DMQM',
#  '/product/1Qg0JKyK',
#  '/product/1kgLFUQ2',
#  '/product/yTt2BjUj',
#  '/product/1ikHAis7',
#  '/product/ypiTKMds',
#  '/product/z72C7UZY',
#  '/product/8sK95gjb',
#  '/product/8SRpC7Dz',
#  '/product/v5xM8p6j',
#  '/product/E9zUiHqs',
#  '/product/HvMQcnQB',
#  '/product/DjVKUQUm',
#  '/product/1YY9cbki',
#  '/product/1U7tzVIb',
#  '/product/cTzXj5JB',
#  '/product/K0U8JoZ5',
#  '/product/LCv66u3L',
#  '/product/n5seG9pt',
#  '/product/nRbPUxtL',
#  '/product/TiwFdRwA',
#  '/product/jn8mKrHZ',
#  '/product/bPDxaHSm',
#  '/product/1SxpaVTA',
#  '/product/1uv-ikRM',
#  '/product/1RGJsKop',
#  '/product/18Pp4R42',
#  '/product/XgSmN66A',
#  '/product/WyvHmpU4',
#  '/product/u3SYHRFP',
#  '/product/xJX7mQuz',
#  '/product/CCSW8aPN',
#  '/product/1IUOOIhT',
#  '/product/10yntuxs',
#  '/product/iPK2L5BD',
#  '/product/jb9rXDP8',
#  '/product/xDtyTCtz',
#  '/product/2HHqnAIV',
#  '/product/mDMTvMSJ',
#  '/product/1ntYS54K',
#  '/product/BHwfpxvt',
#  '/product/1VlMZAYr',
#  '/product/pcTGfCk4',
#  '/product/1XH2yKUH',
#  '/product/TFggYRJt',
#  '/product/JSKaBKrs',
#  '/product/u785uBJt',
#  '/product/1ENuqgvn',
#  '/product/uBK2wpmj',
#  '/product/1X8M2Fix',
#  '/product/1Y9OZOUR',
#  '/product/1zot9Zzf',
#  '/product/1TieK17u',
#  '/product/1h3_6DlQ',
#  '/product/1LlLKbzs',
#  '/product/7feNmR7R',
#  '/product/fqLpbnE4',
#  '/product/1OcjxeVJ',
#  '/product/Z5dfKg46',
#  '/product/VanfkYCf',
#  '/product/3yUGVsTd',
#  '/product/1faycesF',
#  '/product/1j1ym3g1',
#  '/product/HHmNVy5W',
#  '/product/1Jqkxzyl',
#  '/product/Ey6ASKmY',
#  '/product/3w4tCjVp',
#  '/product/WAFKPGv6',
#  '/product/GpNg76aC',
#  '/product/iHcXmFdJ',
#  '/product/CjW5RVnc',
#  '/product/1VdVkhZS',
#  '/product/1ACDrNfC',
#  '/product/tiKs2s7E',
#  '/product/zVL48ZsP',
#  '/product/1QoYdioc',
#  '/product/KDf29a1u',
#  '/product/Kk7Bz36B',
#  '/product/054fgUXl',
#  '/product/yacZ8ZRY',
#  '/product/qXLNWavA',
#  '/product/1Of97u7s',
#  '/product/h3P7nsgE',
#  '/product/JYarZRyu',
#  '/product/JPSLHdGe',
#  '/product/7wrsirbK',
#  '/product/1Ykso3U8',
#  '/product/1thAfaGi',
#  '/product/1o2MnSx6',
#  '/product/1KxPloZe',
#  '/product/1ddmeoqG',
#  '/product/2mjfmDHt',
#  '/product/LfNE4KK2',
#  '/product/1qrgrEl5',
#  '/product/qyDrDFCa',
#  '/product/uhegdwkf',
#  '/product/1eld88kz',
#  '/product/1Gdy6R31',
#  '/product/6xQWazLk',
#  '/product/1otEVRQm',
#  '/product/bDSEV2Ua',
#  '/product/1W1XvGNx',
#  '/product/MxuamZYg',
#  '/product/1hgVHBkN',
#  '/product/1iGobBtE',
#  '/product/10gD9AJK',
#  '/product/B2jwyKcK',
#  '/product/kGyjMthU',
#  '/product/TmJMQn4Y',
#  '/product/Hp6tRVHE',
#  '/product/jXwNsGvH',
#  '/product/1WVCpZDp',
#  '/product/isHQdpjk',
#  '/product/rTeQGPng',
#  '/product/1CIPsOH7',
#  '/product/zYVGbrRg',
#  '/product/qHjsDz7V',
#  '/product/CFD6L892',
#  '/product/1Br0_dOj',
#  '/product/P626crdD',
#  '/product/g9ac5TTw',
#  '/product/B5MB5vmc',
#  '/product/SP4JUtUe',
#  '/product/Gnu5h2Bh',
#  '/product/yLaTEbW9',
#  '/product/f7rxsxbb',
#  '/product/1v1rEpjv',
#  '/product/WfpdcNA6',
#  '/product/1k5FwCTs',
#  '/product/1Urp6LCT',
#  '/product/j4LKy66W',
#  '/product/1c--f4fm',
#  '/product/z7JncXc9',
#  '/product/1ntcWkaP',
#  '/product/1QP4cf0L',
#  '/product/1YLHZSVN',
#  '/product/m4Hzzrzf',
#  '/product/1tZ4HQ3r',
#  '/product/MiUa8FtS',
#  '/product/V4jQZn3K',
#  '/product/13KHA8BD',
#  '/product/1AjB2Ckg',
#  '/product/gy5qkVk8',
#  '/product/1VXypPjX']
